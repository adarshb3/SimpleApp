# %%
pip install streamlit
# Out:
# ...
#                                               0.0/8.9 MB ? eta -:--:--
#                                               0.0/8.9 MB ? eta -:--:--
#                                               0.1/8.9 MB 1.3 MB/s eta 0:00:07
#      -                                        0.2/8.9 MB 1.7 MB/s eta 0:00:06
#      -                                        0.3/8.9 MB 1.5 MB/s eta 0:00:06
#      -                                        0.4/8.9 MB 1.8 MB/s eta 0:00:05
#      --                                       0.6/8.9 MB 2.3 MB/s eta 0:00:04
#      ----                                     0.9/8.9 MB 2.9 MB/s eta 0:00:03
#      -------                                  1.6/8.9 MB 4.1 MB/s eta 0:00:02
#      -----------                              2.6/8.9 MB 6.3 MB/s eta 0:00:01
#      -----------------                        3.9/8.9 MB 8.6 MB/s eta 0:00:01
#      -----------------                        3.9/8.9 MB 8.6 MB/s eta 0:00:01
# ...

# %%
mkdir -p ~/.streamlit/
echo "[server]
headless = true
port = $PORT
enableCORS = false
" > ~/.streamlit/config.toml
# Out:
#   Cell In[2], line 2
#     echo "[server]
#          ^
# SyntaxError: unterminated string literal (detected at line 2)
